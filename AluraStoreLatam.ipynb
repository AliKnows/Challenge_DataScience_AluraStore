# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.sample(10)
# Out:
#                        Producto   Categoría del Producto     Precio  \
# 47                 Set de ollas  Artículos para el hogar   100900.0
# 503                Celular ABXY             Electrónicos   882200.0
# 292                  Cubertería  Artículos para el hogar    58400.0
# 1770        Modelado predictivo                   Libros    62300.0
# 186             Mesa de comedor                  Muebles   217000.0
# 537           Asistente virtual             Electrónicos   182000.0
# 126            Lavadora de ropa        Electrodomésticos  1356900.0
# 670   Iniciando en programación                   Libros    50700.0
# 920         Modelado predictivo                   Libros    47400.0
# 457                   Iphone 15             Electrónicos  1701700.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 47            5600.0      19/07/2021  Mariana Herrera        Medellín
# 503          52800.0      13/02/2023   Blanca Ramirez        Medellín
# ...

# %%
tienda2.sample(10)
# Out:
#                          Producto   Categoría del Producto     Precio  \
# 1552                 Set de ollas  Artículos para el hogar   187000.0
# 691               Sofá reclinable                  Muebles   736600.0
# 1355               Dinosaurio Rex                 Juguetes    13600.0
# 2120                    Iphone 15             Electrónicos  1988600.0
# 2271              Cubo mágico 8x8                 Juguetes    16000.0
# 2190              Olla de presión  Artículos para el hogar    73300.0
# 1723                      Mochila     Deportes y diversión   105400.0
# 73    Ciencia de datos con Python                   Libros    49900.0
# 2105                   Microondas        Electrodomésticos   520600.0
# 256              Secadora de ropa        Electrodomésticos   619000.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 1552         10200.0      23/09/2022    Juliana Costa          Cúcuta
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
ingreso_total_t1 = tienda['Precio'].sum()
ingreso_total_t1
# Out:
# np.float64(1150880400.0)

# %%
ingreso_total_t2 = tienda2['Precio'].sum()
ingreso_total_t2
# Out:
# np.float64(1116343500.0)

# %%
ingreso_total_t3 = tienda3['Precio'].sum()
ingreso_total_t3
# Out:
# np.float64(1098019600.0)

# %%
ingreso_total_t4 = tienda4['Precio'].sum()
ingreso_total_t4
# Out:
# np.float64(1038375700.0)

# %%
#la tienda con menor ingreso
if ingreso_total_t1 < ingreso_total_t2 and ingreso_total_t1 < ingreso_total_t3 and ingreso_total_t1 < ingreso_total_t4:
  print(f"La tienda con menor ingreso es la tienda 1 con :{ingreso_total_t1}")
elif ingreso_total_t2 < ingreso_total_t1 and ingreso_total_t2 < ingreso_total_t3 and ingreso_total_t2 < ingreso_total_t4:
  print(f"La tienda con menor ingreso es la tienda 2 con :{ingreso_total_t2}")
elif ingreso_total_t3 < ingreso_total_t1 and ingreso_total_t3 < ingreso_total_t2 and ingreso_total_t3 < ingreso_total_t4:
  print(f"La tienda con menor ingreso es la tienda 3 con :{ingreso_total_t3}")
elif ingreso_total_t4 < ingreso_total_t1 and ingreso_total_t4 < ingreso_total_t2 and ingreso_total_t4 < ingreso_total_t3:
  print(f"La tienda con menor ingreso es la tienda 4 con :{ingreso_total_t4}")
# Out:
# La tienda con menor ingreso es la tienda 4 con :1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
productos_vendidos_t1 = tienda['Producto'].value_counts()
productos_vendidos_t1
# Out:
# Producto
# Microondas                     60
# TV LED UHD 4K                  60
# Armario                        60
# Secadora de ropa               58
# Mesa de noche                  56
# Bloques de construcción        56
# Balón de baloncesto            55
# Bicicleta                      54
# Vaso térmico                   54
# Refrigerador                   54
# Impresora                      54
# Batería                        53
# Cubertería                     52
# Carrito de control remoto      52
# Modelado predictivo            51
# Auriculares                    50
# Ajedrez de madera              49
# Iphone 15                      49
# Lavavajillas                   48
# Lavadora de ropa               47
# Guitarra eléctrica             47
# Guitarra acústica              46
# Sofá reclinable                46
# Silla de oficina               46
# Estufa                         45
# Cama box                       44
# Kit de bancas                  44
# ...

# %%
productos_vendidos_t2 = tienda2['Producto'].value_counts()
productos_vendidos_t2
# Out:
# Producto
# Iniciando en programación      65
# Microondas                     62
# Batería                        61
# Guitarra acústica              58
# Pandereta                      58
# Secadora de ropa               57
# Iphone 15                      55
# Bloques de construcción        54
# Armario                        54
# Set de ollas                   52
# Cuerda para saltar             50
# Lavadora de ropa               49
# Silla de oficina               49
# Refrigerador                   49
# Muñeca bebé                    48
# Carrito de control remoto      47
# Guitarra eléctrica             47
# Cama box                       47
# Vaso térmico                   47
# Modelado predictivo            46
# Balón de voleibol              46
# Set de vasos                   46
# Lavavajillas                   46
# Kit de bancas                  45
# Cama king                      45
# Bicicleta                      45
# Mochila                        45
# ...

# %%
productos_vendidos_t3 = tienda3['Producto'].value_counts()
productos_vendidos_t3
# Out:
# Producto
# Kit de bancas                  57
# Mesa de comedor                56
# Cama king                      56
# Set de ollas                   55
# Mesa de noche                  55
# Smart TV                       54
# Estufa                         53
# Cuerda para saltar             53
# Modelado predictivo            53
# Carrito de control remoto      52
# Lavavajillas                   52
# Bicicleta                      52
# Juego de mesa                  52
# Pandereta                      51
# Impresora                      50
# Refrigerador                   50
# Balón de baloncesto            50
# Armario                        49
# Balón de voleibol              48
# Tablet ABXY                    48
# Sillón                         47
# Guitarra acústica              47
# Olla de presión                47
# Ajedrez de madera              47
# Ciencia de datos con Python    46
# Iphone 15                      46
# Dinosaurio Rex                 46
# ...

# %%
productos_vendidos_t4 = tienda4['Producto'].value_counts()
productos_vendidos_t4
# Out:
# Producto
# Cama box                       62
# Cubertería                     59
# Dashboards con Power BI        56
# Cama king                      56
# Carrito de control remoto      55
# Mesa de comedor                55
# Mesa de noche                  55
# Smart TV                       54
# Bloques de construcción        54
# Pandereta                      52
# Impresora                      50
# Modelado predictivo            50
# Asistente virtual              50
# Set de ollas                   50
# Balón de baloncesto            50
# Vaso térmico                   48
# Iphone 15                      48
# Muñeca bebé                    48
# Batería                        48
# Balón de voleibol              48
# Juego de mesa                  48
# Microondas                     48
# Estufa                         47
# Cubo mágico 8x8                47
# Sofá reclinable                47
# Dinosaurio Rex                 47
# Olla de presión                46
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
tienda.sample(5)
# Out:
#                        Producto  Categoría del Producto    Precio  \
# 2243          Guitarra acústica  Instrumentos musicales  430700.0
# 662          Guitarra eléctrica  Instrumentos musicales  934500.0
# 2250                 Microondas       Electrodomésticos  705100.0
# 938     Bloques de construcción                Juguetes   40600.0
# 1089  Carrito de control remoto                Juguetes   76500.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 2243         23400.0      12/03/2022  Beatriz Morales        Medellín
# 662          50000.0      01/12/2022    Juliana Costa        Medellín
# 2250         37800.0      29/11/2021   Juan Fernandez        Medellín
# 938              0.0      03/06/2022  Ángel Rodriguez         Pereira
# 1089          4600.0      06/12/2020   Juan Fernandez          Bogotá
#
#       Calificación      Método de pago  Cantidad de cuotas      lat       lon
# ...

# %%
prome_calificacion_t1 = round(tienda['Calificación'].mean(),4)
prome_calificacion_t1
# Out:
# np.float64(3.9767)

# %%
prome_calificacion_t2 = round(tienda2['Calificación'].mean(),4)
prome_calificacion_t2
# Out:
# np.float64(4.0373)

# %%
prome_calificacion_t3 = round(tienda3['Calificación'].mean(),4)
prome_calificacion_t3
# Out:
# np.float64(4.0483)

# %%
prome_calificacion_t4 = round(tienda3['Calificación'].mean(),4)
prome_calificacion_t4
# Out:
# np.float64(4.0483)

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# # 5. Envío promedio por tienda
